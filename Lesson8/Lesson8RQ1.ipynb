# %% [markdown]
# # REVIEW QUESTIONS 1

# %%
from pathlib import Path

#1
file_path = Path.home() / "my_folder" / "my_file.txt"

#2
print("Path exists:", file_path.exists())

#3
print("File name:", file_path.name)

#4
print("Parent directory:", file_path.parent.name)
# Out:
# Path exists: False
# File name: my_file.txt
# Parent directory: my_folder
