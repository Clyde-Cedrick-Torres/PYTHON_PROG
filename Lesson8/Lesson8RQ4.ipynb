# %% [markdown]
# # REVIEW QUESTION 4 STARSHIPS

# %%
from pathlib import Path

file_path = Path.home() / "starships.txt"
lines = ["Discovery", "Enterprise", "Defiant", "Voyager"]

with open(file_path, "w") as f:
    for line in lines:
        f.write(line + "\n")

print("starships.txt created!")
# Out:
# starships.txt created!

# %%
from pathlib import Path

file_path = Path.home() / "starships.txt"

with open(file_path, "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Discovery
# Enterprise
# Defiant
# Voyager
